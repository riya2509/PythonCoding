# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.arange(0,40)

# %%
y=np.arange(10,50)

# %%
a=np.arange(0,10)

# %%
b=np.arange(0,20)

# %%
plt.scatter(x,y,c='b')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph in 2D")
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
y=x*x

# %%
plt.plot(x,y,'r*',markersize=5)

# %% [markdown]
# #Pie chart

# %%
labels='riya','abhi','aryan','ajay','shalu'
sizes=[23,54,78,45,58,]
colors=['gold','red','yellowgreen', 'lightcoral', 'lightskyblue']
explode=(0,0,0.1,0,0.05)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True)
plt.show()
